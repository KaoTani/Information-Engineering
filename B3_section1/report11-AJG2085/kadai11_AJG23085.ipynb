# %% [markdown]
# 学生番号，氏名を記載して下さい．

# %% [raw]
# 学籍番号：AJG23085

# %% [raw]
# 氏名：谷口香央

# %% [markdown]
# # 第11回講義資料
# python のモジュールの1つであるmatplotlib を使ってグラフを描画をしてみましょう．

# %% [markdown]
# ## 必要なモジュールの読み込み
# 今回はnumpy とmatplotlib を利用しますので，予め読み込みをしておきます．

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# もしここを実行してエラーが出る場合は，モジュールがインストールされていません．
# コマンドプロンプト，もしくはターミナルでnumpy は``pip install numpy``，matplotlib は``pip install matplotlib``でインストールして下さい．

# %% [markdown]
# ## 簡単なグラフの描画例
# ここでは，matplolib での棒グラフ，折れ線グラフ，散布図の描画方法を見てみましょう．
# ### グラフのデータの用意
# まずはプロットするデータをnumpy の配列として用意します．x は横軸の値，yは縦軸の値とします．

# %%
#データはリストもしくはnumpy の配列として与える
x = np.array( [ 1, 2 ,3 ] )
y = np.array( [ 10, 20, 30 ] )

# %% [markdown]
# x, y がどのような値か出力してみましょう．

# %%
print('x =', end="")
print( x )
print('y =', end="" )
print( y )
# Out:
# x =[1 2 3]
# y =[10 20 30]

# %% [markdown]
# ### 棒グラフの描画
# まず．棒グラフを描画してみましょう．棒グラフを描画する関数は``plt.bar()``です．また，グラフの描画結果を出力する関数の``plt.show()``を描画の際に呼び出します．

# %%
#棒グラフを描く
plt.bar( x, y )
plt.show()

# %% [markdown]
# ### グラフのカスタマイズ
# では，このグラフの形式はそのままに，グラフのカスタマイズをしてみましょう．
# グラフにタイトルをつけたり，凡例を載せたり，色を変えてみます．

# %%
#グラフのカスタマイズ
plt.bar( x, y, label= 'data1', color = 'pink' )#凡例の名前とグラフの色を指定
plt.title( 'bar')#グラフのタイトルを表示
plt.xlabel( 'x' )#グラフのx軸
plt.ylabel( 'y' )#グラフのy軸
plt.legend()#凡例の表示
plt.xticks( x, [ 'a', 'b', 'c'])#x 軸の目盛りを書き換える
plt.show()

# %% [markdown]
# 上記以外にもフォントの種類やサイズを変えたりすることも可能ですので，自分で調べながらカスタマイズしてみて下さい．
# ### グラフの形式の変更
# 次に，グラフの形式を変えてみます．折れ線グラフとして描画をしてみましょう．

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# また，散布図を描画してみましょう．

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### グラフを画像として保存
# グラフはpdf やeps,jpg などの形式で保存することが出来ます．
# グラフを描画した後，``plt.savefig()``関数を呼び出すと，直前に描画されたグラフがpdf ファイルとして保存されるので，ファイルが保存されたか確認して下さい．

# %%
plt.scatter( x, y, label= 'data1', color = 'darkturquoise', marker = '*', s=300 )#凡例の名前とマーカの色と形状，サイズを指定
plt.title( 'stars', fontsize = 16 )#グラフのタイトルを表示
plt.xlabel( 'x' , fontsize = 16)#グラフのx軸とフォントサイズ
plt.ylabel( 'y', fontsize = 16)#グラフのy軸とフォントサイズ
plt.xticks( fontsize = 16)#横軸の関数を
plt.yticks( fontsize = 16)
plt.legend(fontsize  = 16)#凡例の表示
plt.savefig('plot.pdf', bbox_inches='tight')#pdf として保存

# %% [markdown]
# ## 課題（データを読み込んでグラフを描画）
# csv ファイルからデータを読み込んで，グラフを描画する関数を記載しましょう．
# 今回利用するcsv ファイルは，このファイルと同じディレクトリにある，``sakaicity_population.csv``です．
# このデータは，堺市の年齢別人口統計データです．このファイルをプログラム内で読み込んで来て，男女それぞれ5年間隔の統計データに変換して下さい．
# そして，男女それぞれを棒グラフとして描画するプログラムを以下に書いて下さい．
# グラフの描画方法は特に指定せず，男女別のグラフを描画出来れば良いとします．
# 人口ピラミッドのように1つにまとめてもらっても構いません．
# 参考に，私がmatplotlib で描画したグラフを示しておきます．
# <img src = './pyramid.pdf'>

# %%
#CSV ファイルからのデータ読み込みとデータ描画のコードをここに書いて下さい．
#必要なモジュールがあればここで適宜追加して構いません．
l=[]
l1 = []
with open( 'sakaicity_population.csv', 'r' ) as f:
  for line in f: # ファイルから１行ずつ読み込む
    t = line.strip() # 前後の空白や改行を取り除く
    tw = t.split(',')
    l.append(tw)
del l[:3]

for line1 in l:
    l1.append([s for s in line1 if s != ''])

M = []
F = []
y1 = []
y2 = []
x = []
for i in range(len(l1)):
    M.append(int(l1[i][2]))
    F.append(int(l1[i][3]))
    if i%5 == 4:
        y1.append(sum(M))
        y2.append(sum(F))
        M.clear()
        F.clear()
        x.append(str(i-4) + '-' + str(i))
    if i == 100:
        y1.append(sum(M))
        y2.append(sum(F))
        x.append('100++')
        break
print(x)
print(y1)
print(y2)

#グラフのカスタマイズ
plt.bar( x, y1, color = 'blue' )#凡例の名前とグラフの色を指定
plt.title( 'Male')#グラフのタイトルを表示
plt.xlabel( 'age' )#グラフのx軸
plt.ylabel( 'population' )#グラフのy軸
plt.xticks(rotation=270)
plt.show()

#グラフのカスタマイズ
plt.bar( x, y2, color = 'red' )#凡例の名前とグラフの色を指定
plt.title( 'Female')#グラフのタイトルを表示
plt.xlabel( 'age' )#グラフのx軸
plt.ylabel( 'population' )#グラフのy軸
plt.xticks(rotation=270)
plt.show()

#plt.show()
# Out:
# ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80-84', '85-89', '90-94', '95-99', '100++']
# [17617, 19384, 20484, 21196, 20758, 21106, 22664, 25692, 34156, 33899, 26072, 21447, 21581, 30885, 24792, 21566, 13525, 6019, 1908, 307, 27]
# [16858, 18380, 19372, 20451, 20336, 20575, 22978, 26651, 34580, 33980, 26536, 22260, 23649, 36546, 29166, 26621, 19057, 11642, 5641, 1695, 327]

# %% [markdown]
# ## グラフの描画で工夫した点・課題の感想
# グラフの描画を行った際に，どのような点を工夫したか記入して下さい．また，課題に関して気になる点があれば以下に記載して下さい．

# %% [raw]
# csvファイルをそのまま配列に保存すると、何も書いてない配列ができたので、それを削除することで使いやすい配列に直した。

# %% [markdown]
# ## 提出方法
# 全てのコードを実行した状態にして保存し，ファイルの最初の部分に学籍番号と氏名を記入して，ファイル名のXXX の部分を学籍番号に書き換えて，.ipynb ファイルを[moodle](https://lms.omu.ac.jp/mod/assign/view.php?id=891773)に提出して下さい．締切は7/5 23:59です．
